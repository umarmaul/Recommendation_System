# %% [markdown]
# <a href="https://colab.research.google.com/github/umarmaul/Recommendation_System/blob/main/Content_Based_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv("https://raw.githubusercontent.com/umarmaul/Recommendation_System/main/Dataset/content_by_synopsis.csv")
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...

# %% [markdown]
# #Encode all synopsis menjadi bank

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
bow = CountVectorizer(stop_words="english", tokenizer=word_tokenize)
bank = bow.fit_transform(df.overview)

# %% [markdown]
# #Step 1: Encode what user watch

# %%
idx = 0

# %%
content = df.loc[idx, "overview"]
content
# Out:
# "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences."

# %%
code = bow.transform([content])
code
# Out:
# <1x86599 sparse matrix of type '<class 'numpy.int64'>'
# 	with 28 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #Step 2: Document search

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
dist = cosine_distances(code, bank)
dist
# Out:
# array([[0.        , 0.68698928, 0.70198022, ..., 0.88529213, 0.68931574,
#         0.75277431]])

# %%
rec_idx = dist.argsort()[0, 1:11]
rec_idx
# Out:
# array([14706,  2945,  9984, 36827, 40606, 13404, 22084, 14078,  6172,
#        27006])

# %% [markdown]
# #Step 3: Recommend

# %%
df.loc[rec_idx]
# Out:
#                                  title  \
# 14706                      Toy Story 3
# 2945                       Toy Story 2
# 9984            The 40 Year Old Virgin
# 36827                    Wabash Avenue
# 40606                           Stasis
# 13404              The Gang's All Here
# 22084                   The Pied Piper
# 14078              A Matter of Dignity
# 6172   The Courtship of Eddie's Father
# 27006                        Superdome
#
#                                                 overview
# 14706  Woody, Buzz, and the rest of Andy's toys haven...
# 2945   Andy heads off to Cowboy Camp, leaving his toy...
# 9984   Andy Stitzer has a pleasant life with a nice a...
# 36827  Andy Clark discovers he was cheated out of a h...
# 40606  After a night out of partying and left behind ...
# 13404  Playboy Andy Mason, on leave from the army, ro...
# 22084  Greed, corruption, ignorance, and disease. Mid...
# 14078  During one of her parents many parties, Chloe ...
# 6172   The film that started the classic TV series. A...
# 27006  It's Superbowl. And there's a lot of drama, on...

# %% [markdown]
# #ML Engineering Implementation

# %%
from sklearn.metrics.pairwise import cosine_distances

class RecommenderSystem:
  def __init__(self, data, content_col):
    self.df = pd.read_csv(data)
    self.content_col = content_col
    self.encoder = None
    self.bank = None

  def fit(self):
    self.encoder = CountVectorizer(stop_words="english", tokenizer=word_tokenize)
    self.bank = self.encoder.fit_transform(self.df[self.content_col])

  def recommend(self, idx, topk=10):
    content = df.loc[idx, self.content_col]
    code = self.encoder.transform([content])
    dist = cosine_distances(code, self.bank)
    rec_idx = dist.argsort()[0, 1:(topk+1)]
    return self.df.loc[rec_idx]

# %%
recsys = RecommenderSystem("https://raw.githubusercontent.com/umarmaul/Recommendation_System/main/Dataset/content_by_synopsis.csv", content_col="overview")
recsys.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
recsys.recommend(1) #Jumanji
# Out:
#                                                    title  \
# 27006                                          Superdome
# 40606                                             Stasis
# 37971                                       Snowed Under
# 18715                                     Wreck-It Ralph
# 40431                                  Liar Game: Reborn
# 38232  Enter the Battlefield: Life on the Magic - The...
# 36540                                          Beta Test
# 14859                                    Le Pont du Nord
# 13105                                           Break Up
# 17918                  Dante's Inferno: An Animated Epic
#
#                                                 overview
# 27006  It's Superbowl. And there's a lot of drama, on...
# 40606  After a night out of partying and left behind ...
# 37971  Alan Tanner's new play opens in a week, but Ta...
# 18715  Wreck-It Ralph is the 9-foot-tall, 643-pound v...
# 40431  To exact revenge, the Liar Game office is revi...
# 38232  Magic: The Gathering is the most popular colle...
# 36540  While testing the latest first person shooter ...
# 14859  Marie, is just out from prison when she runs i...
# 13105  Jimmy is married to the abusive Frank, but she...
# 17918  Dante journeys through the nine circles of Hel...

# %%
recsys.recommend(579) #Home Alone
# Out:
#                                          title  \
# 1959                       The Return of Jafar
# 34229                 The Princess and the Pea
# 26972                  For a Handful of Kisses
# 25328  War and Peace, Part II: Natasha Rostova
# 18759               The Well Digger's Daughter
# 26411                           Lost and Found
# 27938                               Streetwise
# 41081                          Ordinary Wonder
# 10890                   The Tiger and the Snow
# 34417                          Dudes & Dragons
#
#                                                 overview
# 1959   The evil Jafar escapes from the magic lamp as ...
# 34229  In one of the realms, there was time for the p...
# 26972  A girl. A boy. A love story. But also about dr...
# 25328  In the end of 1809, Natasha attends her first ...
# 18759  It's the beginning of the WWII. South of Franc...
# 26411  While visiting Switzerland, an American colleg...
# 27938  Portrays the lives of nine desperate teenagers...
# 41081  In a romantic and philosophical tale of magic ...
# 10890  Love and injury in time of war. Attilio de Gio...
# 34417  When the powerful wizard, Lord Tensley, is jil...

# %% [markdown]
# #Multiple Information using Metadata soup

# %%
df = pd.read_csv("https://raw.githubusercontent.com/umarmaul/Recommendation_System/main/Dataset/content_by_multiple.csv")
df.head()
# Out:
#                          title                    genres  \
# 0                    Toy Story   animation comedy family
# 1                      Jumanji  adventure fantasy family
# 2             Grumpier Old Men            romance comedy
# 3            Waiting to Exhale      comedy drama romance
# 4  Father of the Bride Part II                    comedy
#
#                                             cast  \
# 0                tom_hanks tim_allen don_rickles
# 1     robin_williams jonathan_hyde kirsten_dunst
# 2         walter_matthau jack_lemmon ann-margret
# 3  whitney_houston angela_bassett loretta_devine
# 4         steve_martin diane_keaton martin_short
#
#                                             keywords         director  \
# 0                                   jealousy toy boy    john_lasseter
# 1  board_game disappearance based_on_children's_book     joe_johnston
# 2           fishing best_friend duringcreditsstinger    howard_deutch
# 3  based_on_novel interracial_relationship single...  forest_whitaker
# 4                     baby midlife_crisis confidence    charles_shyer
#
#                                             metadata
# 0  animation comedy family tom_hanks tim_allen do...
# 1  adventure fantasy family robin_williams jonath...
# 2  romance comedy walter_matthau jack_lemmon ann-...
# 3  comedy drama romance whitney_houston angela_ba...
# 4  comedy steve_martin diane_keaton martin_short ...

# %%
recsys = RecommenderSystem("https://raw.githubusercontent.com/umarmaul/Recommendation_System/main/Dataset/content_by_multiple.csv", content_col="metadata")
recsys.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
recsys.recommend(0) #Toy Story
# Out:
#                                                 title  \
# 2963                                      Toy Story 2
# 14771                                     Toy Story 3
# 24390                            The Legend of Mor'du
# 3273                                Creature Comforts
# 25917                   A Flintstones Christmas Carol
# 41974                                          Banana
# 34722                       Open Season: Scared Silly
# 25857       I Want a Dog for Christmas, Charlie Brown
# 29030               Tom and Jerry: Shiver Me Whiskers
# 37061  VeggieTales: The Ultimate Silly Song Countdown
#
#                         genres                             cast  \
# 2963   animation comedy family  tom_hanks tim_allen joan_cusack
# 14771  animation family comedy   tom_hanks tim_allen ned_beatty
# 24390         animation family  tom_hanks tim_allen joan_cusack
# 3273   animation comedy family                              NaN
# 25917  animation comedy family                              NaN
# 41974  animation comedy family                              NaN
# 34722  animation comedy family                              NaN
# 25857  animation comedy family                              NaN
# 29030  animation comedy family                  pablo_francisco
# 37061         animation family                              NaN
#
#                                  keywords           director  \
# 2963   museum prosecution identity_crisis      john_lasseter
# 14771                 hostage college toy        lee_unkrich
# 24390                 toy short toy_story      steve_purcell
# 3273                            animation          nick_park
# 25917                                 NaN        rein_raamat
# 41974                                 NaN       adam_foulkes
# 34722                                 NaN  dee_hibbert-jones
# 25857                                 NaN       dony_permedi
# 29030                                 NaN                NaN
# 37061                                 NaN                NaN
#
#                                                 metadata
# 2963   animation comedy family tom_hanks tim_allen jo...
# 14771  animation family comedy tom_hanks tim_allen ne...
# 24390  animation family tom_hanks tim_allen joan_cusa...
# 3273        animation comedy family  animation nick_park
# 25917              animation comedy family   rein_raamat
# 41974             animation comedy family   adam_foulkes
# 34722        animation comedy family   dee_hibbert-jones
# 25857             animation comedy family   dony_permedi
# 29030          animation comedy family pablo_francisco
# 37061                                animation family

# %%
recsys.recommend(1) #Jumanji
# Out:
#                                         title                          genres  \
# 41600                  The Kingdom of Fairies               adventure fantasy
# 28394                          The Rain Fairy                  family fantasy
# 39899              Tainá: An Amazon Adventure        family fantasy adventure
# 552                            The Pagemaster  fantasy science_fiction family
# 40803                     Princess Goldilocks        adventure family fantasy
# 14070  Playmobil: The Secret of Pirate Island         action adventure family
# 15781               Cirque du Soleil: Varekai            drama family fantasy
# 21579    The Young and Prodigious T.S. Spivet          adventure drama family
# 12560                           City of Ember        adventure family fantasy
# 17504          G.I. Joe: The Revenge of Cobra           family fantasy action
#
#                                                     cast  \
# 41600                                                NaN
# 28394                                                NaN
# 39899                                                NaN
# 552    macaulay_culkin christopher_lloyd patrick_stewart
# 40803                                     charlie_durkin
# 14070                        lee_tockar caitlin_williams
# 15781                                                NaN
# 21579                                                NaN
# 12560       saoirse_ronan harry_treadaway mary_kay_place
# 17504                                                NaN
#
#                                 keywords               director  \
# 41600                                NaN                    NaN
# 28394                                NaN                    NaN
# 39899                             comedy       kahane_cooperman
# 552      library adventure part_animated           joe_johnston
# 40803                     woman_director        callie_t._wiser
# 14070          fantasy adventure cartoon  alexander_e._sokoloff
# 15781                                NaN                    NaN
# 21579                                NaN                    NaN
# 12560  underground_world mayor adventure              gil_kenan
# 17504                                NaN                    NaN
#
#                                                 metadata
# 41600                               adventure fantasy
# 28394                                  family fantasy
# 39899  family fantasy adventure  comedy kahane_cooperman
# 552    fantasy science_fiction family macaulay_culkin...
# 40803  adventure family fantasy charlie_durkin woman_...
# 14070  action adventure family lee_tockar caitlin_wil...
# 15781                            drama family fantasy
# 21579                          adventure drama family
# 12560  adventure family fantasy saoirse_ronan harry_t...
# 17504                           family fantasy action

# %%
recsys.recommend(579) #Home Alone
# Out:
#                                     title                   genres  \
# 2808       Home Alone 2: Lost in New York  comedy family adventure
# 19021                           Nativity!            comedy family
# 34843     Father of Four: Never Gives Up!            comedy family
# 369                           Ri¢hie Ri¢h            comedy family
# 39019  Good Luck Charlie, It's Christmas!            comedy family
# 41843             50 Kilos of Sour Cherry      family drama comedy
# 25916    Norm MacDonald: Me Doing Standup                   comedy
# 30648                  Oh How It Hurts 66            comedy family
# 23872          Welcome, or No Trespassing            comedy family
# 31241                           Get Santa            family comedy
#
#                                                    cast  \
# 2808         macaulay_culkin joe_pesci catherine_o'hara
# 19021      daniel_stern braeden_lemasters stacey_travis
# 34843                                               NaN
# 369    macaulay_culkin john_larroquette edward_herrmann
# 39019                                               NaN
# 41843                                               NaN
# 25916                                               NaN
# 30648                                               NaN
# 23872                                               NaN
# 31241                                               NaN
#
#                                 keywords               director  \
# 2808      holiday new_york new_york_city         chris_columbus
# 19021                            holiday           brian_levant
# 34843                                NaN                    NaN
# 369    family life_raft private_airplane          donald_petrie
# 39019                                NaN  william_k.l._dickson_
# 41843                                NaN                    NaN
# 25916                            holiday           timothy_quay
# 30648                                NaN         bertrand_avril
# 23872                                NaN            elem_klimov
# 31241                                NaN      karin_steinberger
#
#                                                 metadata
# 2808   comedy family adventure macaulay_culkin joe_pe...
# 19021  comedy family daniel_stern braeden_lemasters s...
# 34843                                   comedy family
# 369    comedy family macaulay_culkin john_larroquette...
# 39019              comedy family   william_k.l._dickson_
# 41843                             family drama comedy
# 25916                       comedy  holiday timothy_quay
# 30648                     comedy family   bertrand_avril
# 23872                        comedy family   elem_klimov
# 31241                  family comedy   karin_steinberger
